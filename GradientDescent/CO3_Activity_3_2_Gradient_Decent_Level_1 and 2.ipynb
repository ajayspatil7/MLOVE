# %% [markdown]
# **Prepared by:**
#
# Prof. Ashwini Kumar Mathur<br>
# Assistant Professor<br>
# SoCSE

# %% [markdown]
# ## What is Gradient Decent?
#
# Gradient descent is an optimization algorithm commonly used in machine learning and other fields to minimize a function.
#
#
# ### **Key points about gradient descent:**
#
# - It's an iterative algorithm, meaning it takes small steps repeatedly.
# - It needs a function to optimize, like a loss function in machine learning.
# - It requires a learning rate, which controls the size of the steps it takes.
# - It's not guaranteed to find the global minimum, but it usually finds a good local minimum

# %%
import numpy as np

# Define sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Implement a simple linear model
def model(x, w, b):
    return w * x + b

# Define the mean squared error loss function
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

# Set initial parameters
w = 1
b = 0

# %% [markdown]
# ### Implementation of Gradient Decent

# %%
# Learning rate
learning_rate = 0.001

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = mean_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    print("Iteration:", i, "Loss:", loss)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)
# Out:
# Iteration: 0 Loss: 1.8
# Iteration: 1 Loss: 1.7769097600000006
# Iteration: 2 Loss: 1.7548731877811208
# Iteration: 3 Loss: 1.73384102736633
# Iteration: 4 Loss: 1.7137663261693201
# Iteration: 5 Loss: 1.6946043272789286
# Iteration: 6 Loss: 1.6763123667807687
# Iteration: 7 Loss: 1.6588497758804959
# Iteration: 8 Loss: 1.6421777876041799
# Iteration: 9 Loss: 1.6262594478617316
# Iteration: 10 Loss: 1.611059530669353
# Iteration: 11 Loss: 1.5965444573365162
# Iteration: 12 Loss: 1.5826822194320802
# Iteration: 13 Loss: 1.5694423053528088
# Iteration: 14 Loss: 1.5567956303258361
# Iteration: 15 Loss: 1.544714469684493
# Iteration: 16 Loss: 1.5331723952644123
# Iteration: 17 Loss: 1.522144214774004
# Iteration: 18 Loss: 1.5116059140002092
# Iteration: 19 Loss: 1.5015346017169315
# Iteration: 20 Loss: 1.4919084571697734
# Iteration: 21 Loss: 1.4827066800165865
# Iteration: 22 Loss: 1.473909442609002
# Iteration: 23 Loss: 1.4654978445054652
# Iteration: 24 Loss: 1.4574538691114125
# Iteration: 25 Loss: 1.4497603423471297
# Iteration: 26 Loss: 1.4424008932484615
# Iteration: 27 Loss: 1.4353599164099857
# Iteration: 28 Loss: 1.428622536184493
# Iteration: 29 Loss: 1.4221745725566373
# Iteration: 30 Loss: 1.4160025086124715
# Iteration: 31 Loss: 1.4100934595302312
# Iteration: 32 Loss: 1.404435143021236
# Iteration: 33 Loss: 1.3990158511530848
# Iteration: 34 Loss: 1.3938244234905137
# Iteration: 35 Loss: 1.388850221492288
# Iteration: 36 Loss: 1.3840831041053998
# Iteration: 37 Loss: 1.379513404500577
# Iteration: 38 Loss: 1.3751319078957258
# Iteration: 39 Loss: 1.3709298304164428
# Iteration: 40 Loss: 1.366898798945089
# Iteration: 41 Loss: 1.3630308319121986
# Iteration: 42 Loss: 1.359318320986159
# Iteration: 43 Loss: 1.355754013619155
# Iteration: 44 Loss: 1.352330996409329
# Iteration: 45 Loss: 1.349042679240995
# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = mean_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # Plot updated line
    if i % 10 == 0:  # Plot every 10 iterations for better visualization
        plt.plot(x, model(x, w, b), color='green', alpha=0.3)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)

# Plot final line
plt.plot(x, model(x, w, b), color='blue', label='Final line')

# Add labels and legend
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.title('Gradient Descent Visualization')

# Show the plot
plt.show()
# Out:
# Final w: 1.00335504486389
# Final b: 0.34553740739359207
# Final loss: 1.2276075608763026

# %% [markdown]
# Level - 1
# Changing the Values:
# Parameters and learning rates

# %% [markdown]
# Changing the parameters

# %%
import numpy as np

# Define sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Implement a simple linear model
def model(x, w, b):
    return w * x + b

# Define the mean squared error loss function
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

# Set initial parameters
w = 9
b = 3
# Learning rate
learning_rate = 0.001
#w=theta1
#b=bias->theta0

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = mean_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # print("Iteration:", i, "Loss:", loss)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)
# Out:
# Final w: 1.7099842849609532
# Final b: 1.0315441482963084
# Final loss: 7.94974130714918

# %%
#Using Random Integers between 0 and 10
import numpy as np
import random
# Define sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Implement a simple linear model
def model(x, w, b):
    return w * x + b

# Define the mean squared error loss function
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

# Set initial parameters
w = random.randint(0,10)
b = random.randint(0,10)
# Learning rate
learning_rate = 0.001
#w=theta1
#b=bias->theta0

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = mean_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # print("Iteration:", i, "Loss:", loss)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)
# Out:
# Final w: 0.04109877910767294
# Final b: 5.775160920231329
# Final loss: 4.810660774423409

# %% [markdown]
# Changing the learning rates

# %%
#Using A very High Learning rate


import numpy as np

# Define sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Implement a simple linear model
def model(x, w, b):
    return w * x + b

# Define the mean squared error loss function
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

# Set initial parameters
w = 1
b = 5
# Learning rate
learning_rate = 10.5 #High/Faster Learning Rate
#w=theta1
#b=bias->theta0

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = mean_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    print("Iteration:", i, "Loss:", loss)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)
# Out:
# Iteration: 0 Loss: 16.8
# Iteration: 1 Loss: 929782.5600000002
# Iteration: 2 Loss: 56931497028.0
# Iteration: 3 Loss: 3486000812008515.0
# Iteration: 4 Loss: 2.1345304982398943e+20
# Iteration: 5 Loss: 1.3070049875552158e+25
# Iteration: 6 Loss: 8.002987255992919e+29
# Iteration: 7 Loss: 4.900348937412094e+34
# Iteration: 8 Loss: 3.000557034551535e+39
# Iteration: 9 Loss: 1.8372860040353422e+44
# Iteration: 10 Loss: 1.1249977326722192e+49
# Iteration: 11 Loss: 6.888529579705481e+53
# Iteration: 12 Loss: 4.2179498137978024e+58
# Iteration: 13 Loss: 2.582713832590899e+63
# Iteration: 14 Loss: 1.5814343544904334e+68
# Iteration: 15 Loss: 9.683359364106218e+72
# Iteration: 16 Loss: 5.929265941907346e+77
# Iteration: 65 Loss: 4.8584484600322115
# Iteration: 66 Loss: 4.828891773031929
# Iteration: 67 Loss: 4.799534608249301
# Iteration: 68 Loss: 4.770375618810915
# Iteration: 69 Loss: 4.741413466935426
# Iteration: 70 Loss: 4.712646823872178
# Iteration: 71 Loss: 4.684074369840236
# Iteration: 72 Loss: 4.655694793967847
# Iteration: 73 Loss: 4.627506794232286
# Iteration: 74 Loss: 4.599509077400119
# Iteration: 75 Loss: 4.571700358967884
# Iteration: 76 Loss: 4.544079363103149
# Iteration: 77 Loss: 4.516644822585979
# Iteration: 78 Loss: 4.489395478750798
# Iteration: 79 Loss: 4.462330081428645
# Iteration: 80 Loss: 4.435447388889816
# Iteration: 81 Loss: 4.408746167786897
# Iteration: 82 Loss: 4.382225193098172
# Iteration: 83 Loss: 4.3558832480714305
# Iteration: 84 Loss: 4.329719124168141
# Iteration: 85 Loss: 4.303731621007997
# Iteration: 86 Loss: 4.277919546313856
# Iteration: 87 Loss: 4.252281715857035
# Iteration: 88 Loss: 4.22681695340298
# Iteration: 89 Loss: 4.201524090657289
# Iteration: 90 Loss: 4.176401967212141
# Iteration: 91 Loss: 4.151449430493026
# Iteration: 92 Loss: 4.126665335705885
# Iteration: 93 Loss: 4.102048545784589
# Iteration: 94 Loss: 4.077597931338762
# Iteration: 95 Loss: 4.053312370601965
# Iteration: 96 Loss: 4.029190749380246
# Iteration: 97 Loss: 4.005231961001002
# Iteration: 98 Loss: 3.9814349062622227
# Iteration: 99 Loss: 3.9577984933820516
# Final w: -0.6066448039895123
# Final b: 6.556370608769673
# Final loss: 3.9577984933820516

# %% [markdown]
# ## Class activity excercise : [Intermediate Level ]
#
# Give the short inference via experiment by using differnt loss functions. Inject outliers into dataset and observe what is happening to the loss value. Write your understanding in two to three lines.

# %% [markdown]
# When we change the learning rates and the parameter values, the optimization is affected. Faster learning rates can lead to overshoot and a very slow learning rate may lead to slower convergence of the function. It depends on choosing loss functions which helps in finding the optimum fit.

# %% [markdown]
# Different loss Functions

# %%
import numpy as np

# Define sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Implement a simple linear model
def model(x, w, b):
    return w * x + b

# Define the squared error loss function
def squared_error(y_true, y_pred):
    return (np.sum((y_true - y_pred)**2))

# Define the root mean squared error loss function
def root_mean_squared_error(y_true, y_pred):
    return (np.sqrt(np.mean(y_true - y_pred)**2))

# Define the root squared error loss function
def root_squared_error(y_true, y_pred):
    return (np.sqrt(np.sum((y_true - y_pred)**2)))

# Define the absolute mean error loss function
def abs_mean_error(y_true, y_pred):
    return (abs(np.mean((y_true - y_pred))))

# %% [markdown]
# 1. Squared Error

# %%
# Set initial parameters
w = 11
b = 7
# Learning rate
learning_rate = 0.01
#w=theta1
#b=bias->theta0

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # print("Iteration:", i, "Loss:", loss)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)
# Out:
# Final w: 0.24809318896977872
# Final b: 3.470495247325189
# Final loss: 3.87900918221932

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set initial parameters
w = 11
b = 7
# Learning rate
learning_rate = 0.01


# Plot initial data and line
plt.scatter(x, y, label='Data points')
plt.plot(x, model(x, w, b), color='red', label='Initial line')

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss
# Iteration: 51 Loss: 0.18070554607105116
# Iteration: 52 Loss: 0.18009458746796597
# Iteration: 53 Loss: 0.1794856944927643
# Iteration: 54 Loss: 0.17887886016163704
# Iteration: 55 Loss: 0.1782740775143857
# Iteration: 56 Loss: 0.17767133961434559
# Iteration: 57 Loss: 0.17707063954830363
# Iteration: 58 Loss: 0.17647197042641985
# Iteration: 59 Loss: 0.17587532538214995
# Iteration: 60 Loss: 0.17528069757216347
# Iteration: 61 Loss: 0.1746880801762683
# Iteration: 62 Loss: 0.17409746639733018
# Iteration: 63 Loss: 0.17350884946119569
# Iteration: 64 Loss: 0.17292222261661622
# Iteration: 65 Loss: 0.1723375791351663
# Iteration: 66 Loss: 0.17175491231117118
# Iteration: 67 Loss: 0.1711742154616272
# Iteration: 68 Loss: 0.1705954819261244
# Iteration: 69 Loss: 0.17001870506677336
# Iteration: 70 Loss: 0.16944387826812565
# Iteration: 71 Loss: 0.16887099493710006
# Iteration: 72 Loss: 0.16830004850290575
# Iteration: 73 Loss: 0.1677310324169686
# Iteration: 74 Loss: 0.16716394015285402
# Iteration: 75 Loss: 0.16659876520619338
# Iteration: 76 Loss: 0.16603550109460885
# Iteration: 77 Loss: 0.16547414135763966
# Iteration: 78 Loss: 0.16491467955666747
# Iteration: 79 Loss: 0.16435710927484254
# Iteration: 80 Loss: 0.16380142411701035
# Iteration: 81 Loss: 0.16324761770963808
# Iteration: 82 Loss: 0.16269568370074133
# Iteration: 83 Loss: 0.1621456157598124
# Iteration: 84 Loss: 0.16159740757774524
# Iteration: 85 Loss: 0.1610510528667665
# Iteration: 86 Loss: 0.16050654536036077
# Iteration: 87 Loss: 0.15996387881319923
# Iteration: 88 Loss: 0.15942304700106735
# Iteration: 89 Loss: 0.15888404372079706
# Iteration: 90 Loss: 0.15834686279019072
# Iteration: 91 Loss: 0.15781149804795308
# Iteration: 92 Loss: 0.15727794335362058
# Iteration: 93 Loss: 0.15674619258748929
# Iteration: 94 Loss: 0.15621623965054673
# Iteration: 95 Loss: 0.15568807846440044
# Iteration: 96 Loss: 0.15516170297120882
# Iteration: 97 Loss: 0.1546371071336118
# Iteration: 98 Loss: 0.1541142849346607
# Iteration: 99 Loss: 0.15359323037775133
# Final w: 0.34918958070252454
# Final b: 3.1055051953789787
# Final loss: 0.15359323037775133

# %%
import numpy as np
import matplotlib.pyplot as plt
# Set initial parameters
w = 11
b = 7

# Learning rate
learning_rate = 0.01
# Plot initial data and line
plt.scatter(x, y, label='Data points')
plt.plot(x, model(x, w, b), color='red', label='Initial line')

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = root_mean_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # Plot updated line
    if i % 10 == 0:  # Plot every 10 iterations for better visualization
        plt.plot(x, model(x, w, b), color='green', alpha=0.3)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)

# Plot final line
plt.plot(x, model(x, w, b), color='blue', label='Final line')

# Add labels and legend
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.title('Gradient Descent Visualization')

# Show the plot
plt.show()
# Out:
# Final w: 0.24809318896977872
# Final b: 3.470495247325189
# Final loss: 0.21550342316182647

# %% [markdown]
# 3. Root Squared Error

# %%
# Set initial parameters
w = 11
b = 7
# Learning rate
learning_rate = 0.01
#w=theta1
#b=bias->theta0

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = root_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # print("Iteration:", i, "Loss:", loss)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)
# Out:
# Final w: 0.24809318896977872
# Final b: 3.470495247325189
# Final loss: 1.969520038542213

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set initial parameters
w = 11
b = 7
# Learning rate
learning_rate = 0.01

# Plot initial data and line
plt.scatter(x, y, label='Data points')
plt.plot(x, model(x, w, b), color='red', label='Initial line')

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = root_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # Plot updated line
    if i % 10 == 0:  # Plot every 10 iterations for better visualization
        plt.plot(x, model(x, w, b), color='green', alpha=0.3)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)

# Plot final line
plt.plot(x, model(x, w, b), color='blue', label='Final line')

# Add labels and legend
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.title('Gradient Descent Visualization')

# Show the plot
plt.show()
# Out:
# Final w: 0.24809318896977872
# Final b: 3.470495247325189
# Final loss: 1.969520038542213

# %% [markdown]
# 4. Mean absolute error

# %%
# Set initial parameters
w = 11
b = 7
# Learning rate
learning_rate = 0.01
#w=theta1
#b=bias->theta0

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = abs_mean_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # print("Iteration:", i, "Loss:", loss)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)
# Out:
# Final w: 0.24809318896977872
# Final b: 3.470495247325189
# Final loss: 0.21550342316182647

# %%
import numpy as np
import matplotlib.pyplot as plt


# Set initial parameters
w = 11
b = 7
# Learning rate
learning_rate = 0.01



# Plot initial data and line
plt.scatter(x, y, label='Data points')
plt.plot(x, model(x, w, b), color='red', label='Initial line')

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = abs_mean_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # Plot updated line
    if i % 10 == 0:  # Plot every 10 iterations for better visualization
        plt.plot(x, model(x, w, b), color='green', alpha=0.3)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)

# Plot final line
plt.plot(x, model(x, w, b), color='blue', label='Final line')

# Add labels and legend
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.title('Gradient Descent Visualization')

# Show the plot
plt.show()
# Out:
# Final w: 0.24809318896977872
# Final b: 3.470495247325189
# Final loss: 0.21550342316182647

# %% [markdown]
# ## Class activity excercise : [Intermediate Level ]
#
# Give the short inference via experiment by using differnt loss functions. Inject outliers into dataset and observe what is happening to the loss value. Write your understanding in two to three lines.

# %%
"""
When used different loss functions with the same parameter values and learning rate, we observed different model fits and loss values.

Comparison of loss for different functions,

squaredError(3.87900918221932)
RMSE(0.21550342316182647)
RSE(1.969520038542213)
MAE(0.21550342316182647)

This suggests that choosing the right loss function can significantly impact the model's performance and optimization.
"""
# Out:
# "\nWhen used different loss functions with the same parameter values and learning rate, we observed different model fits and loss values.\n\nComparison of loss for different functions,\n\nsquaredError(3.87900918221932)\nRMSE(0.21550342316182647)\nRSE(1.969520038542213)\nMAE(0.21550342316182647)\n\nThis suggests that choosing the right loss function can significantly impact the model's performance and optimization.\n"
