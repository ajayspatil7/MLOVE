# %% [markdown]
# **Prepared by:**
#
# Prof. Ashwini Kumar Mathur<br>
# Assistant Professor<br>
# SoCSE

# %% [markdown]
# ## What is Gradient Decent?
#
# Gradient descent is an optimization algorithm commonly used in machine learning and other fields to minimize a function.
#
#
# ### **Key points about gradient descent:**
#
# - It's an iterative algorithm, meaning it takes small steps repeatedly.
# - It needs a function to optimize, like a loss function in machine learning.
# - It requires a learning rate, which controls the size of the steps it takes.
# - It's not guaranteed to find the global minimum, but it usually finds a good local minimum

# %%
import numpy as np

# Define sample data
x = np.array([1, 2, 3, 4, 5, 6])
y = np.array([2, 4, 5, 4, 5, 50])

# Implement a simple linear model
def model(x, w, b):
    return w * x + b

# Define the mean squared error loss function
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

# Set initial parameters
w = 1
b = 0

# %% [markdown]
# ### Implementation of Gradient Decent

# %%
# Learning rate
learning_rate = 0.001

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = mean_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    print("Iteration:", i, "Loss:", loss)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)
# Out:
# Iteration: 0 Loss: 324.1666666666667
# Iteration: 1 Loss: 315.6353005740741
# Iteration: 2 Loss: 307.6391633411078
# Iteration: 3 Loss: 300.1445822600137
# Iteration: 4 Loss: 293.1200031339375
# Iteration: 5 Loss: 286.5358569912339
# Iteration: 6 Loss: 280.36443518541836
# Iteration: 7 Loss: 274.57977235317946
# Iteration: 8 Loss: 269.15753673606645
# Iteration: 9 Loss: 264.0749274025639
# Iteration: 10 Loss: 259.3105779364212
# Iteration: 11 Loss: 254.8444661844101
# Iteration: 12 Loss: 250.65782968228464
# Iteration: 13 Loss: 246.7330864017001
# Iteration: 14 Loss: 243.053760483324
# Iteration: 15 Loss: 239.60441264243264
# Iteration: 16 Loss: 236.37057495302705
# Iteration: 17 Loss: 233.33868973499239
# Iteration: 18 Loss: 230.4960522861595
# Iteration: 19 Loss: 227.83075721736836
# Iteration: 20 Loss: 225.3316481638491
# Iteration: 21 Loss: 222.98827066050262
# Iteration: 22 Loss: 220.79082798202236
# Iteration: 23 Loss: 218.73013976132745
# Iteration: 24 Loss: 216.79760321150755
# Iteration: 25 Loss: 214.98515678748194
# Iteration: 26 Loss: 213.2852461338787
# Iteration: 27 Loss: 211.6907921752946
# Iteration: 28 Loss: 210.19516121415197
# Iteration: 29 Loss: 208.79213690984156
# Iteration: 30 Loss: 207.47589402079223
# Iteration: 31 Loss: 206.24097379855394
# Iteration: 32 Loss: 205.0822609299561
# Iteration: 33 Loss: 203.99496192994593
# Iteration: 34 Loss: 202.974584893837
# Iteration: 35 Loss: 202.0169205234413
# Iteration: 36 Loss: 201.11802434693791
# Iteration: 37 Loss: 200.27420005737554
# Iteration: 38 Loss: 199.48198389942957
# Iteration: 39 Loss: 198.73813003846325
# Iteration: 40 Loss: 198.0395968500919
# Iteration: 41 Loss: 197.3835340723358
# Iteration: 42 Loss: 196.767270766093
# Iteration: 43 Loss: 196.18830403307706
# Iteration: 44 Loss: 195.64428844356303
# Iteration: 45 Loss: 195.13302612928456
# Iteration: 46 Loss: 194.65245749963515
# Iteration: 47 Loss: 194.20065254195666
# Iteration: 48 Loss: 193.77580266916956
# Iteration: 49 Loss: 193.376213080307
# Iteration: 50 Loss: 193.00029560168502
# Iteration: 51 Loss: 192.64656197846875
# Iteration: 52 Loss: 192.31361758829834
# Iteration: 53 Loss: 192.00015555042106
# Iteration: 54 Loss: 191.70495120544624
# Iteration: 55 Loss: 191.42685694240504
# Iteration: 56 Loss: 191.16479735126492
# Iteration: 57 Loss: 190.9177646804227
# Iteration: 58 Loss: 190.6848145799885
# Iteration: 59 Loss: 190.4650621128802
# Iteration: 60 Loss: 190.2576780168788
# Iteration: 61 Loss: 190.06188520185628
# Iteration: 62 Loss: 189.87695546737936
# Iteration: 63 Loss: 189.70220642682463
# Iteration: 64 Loss: 189.5369986250124
# Iteration: 65 Loss: 189.380732837184
# Iteration: 66 Loss: 189.2328475379135
# Iteration: 67 Loss: 189.0928165292621
# Iteration: 68 Loss: 188.96014671815706
# Iteration: 69 Loss: 188.834376033606
# Iteration: 70 Loss: 188.71507147494947
# Iteration: 71 Loss: 188.6018272829076
# Iteration: 72 Loss: 188.49426322569443
# Iteration: 73 Loss: 188.392022992961
# Iteration: 74 Loss: 188.29477269078413
# Iteration: 75 Loss: 188.20219943134137
# Iteration: 76 Loss: 188.1140100113175
# Iteration: 77 Loss: 188.0299296734576
# Iteration: 78 Loss: 187.94970094603786
# Iteration: 79 Loss: 187.87308255535035
# Iteration: 80 Loss: 187.79984840660825
# Iteration: 81 Loss: 187.7297866289682
# Iteration: 82 Loss: 187.66269868063384
# Iteration: 83 Loss: 187.59839851026206
# Iteration: 84 Loss: 187.53671177112938
# Iteration: 85 Loss: 187.4774750847386
# Iteration: 86 Loss: 187.42053535075559
# Iteration: 87 Loss: 187.36574910036117
# Iteration: 88 Loss: 187.31298189028686
# Iteration: 89 Loss: 187.26210773497488
# Iteration: 90 Loss: 187.21300857446326
# Iteration: 91 Loss: 187.16557377574927
# Iteration: 92 Loss: 187.1196996655242
# Iteration: 93 Loss: 187.0752890923064
# Iteration: 94 Loss: 187.03225101612205
# Iteration: 95 Loss: 186.99050012400156
# Iteration: 96 Loss: 186.94995646966694
# Iteration: 97 Loss: 186.9105451358877
# Iteration: 98 Loss: 186.87219591808014
# Iteration: 99 Loss: 186.83484302781252
# Final w: 3.8327800959820117
# Final b: 0.162932652955849
# Final loss: 186.83484302781252

# %%
import numpy as np
import matplotlib.pyplot as plt

import numpy as np

# Define sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Set initial parameters
w = 0
b = 0


# Learning rate
learning_rate = 0.001

# Function to calculate predictions
def model(x, w, b):
    return w * x + b

# Function to calculate mean squared error
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

# Plot initial data and line
plt.scatter(x, y, label='Data points')
plt.plot(x, model(x, w, b), color='red', label='Initial line')

# Gradient descent loop
for i in range(100):
    y_pred = model(x, w, b)
    loss = mean_squared_error(y, y_pred)

    # Calculate gradients
    dw = np.mean(2 * x * (y_pred - y))
    db = np.mean(2 * (y_pred - y))

    # Update parameters
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # Plot updated line
    if i % 10 == 0:  # Plot every 10 iterations for better visualization
        plt.plot(x, model(x, w, b), color='green', alpha=0.3)

# Print final parameters and loss
print("Final w:", w)
print("Final b:", b)
print("Final loss:", loss)

# Plot final line
plt.plot(x, model(x, w, b), color='blue', label='Final line')

# Add labels and legend
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.title('Gradient Descent Visualization')

# Show the plot
plt.show()
# Out:
# Final w: 1.00335504486389
# Final b: 0.34553740739359207
# Final loss: 1.2276075608763026

# %% [markdown]
# ## Class activity excercise : [Intermediate Level ]
#
# Give the short inference via experiment by using differnt loss functions. Inject outliers into dataset and observe what is happening to the loss value. Write your understanding in two to three lines.

# %%
"""
Now we can see that, after introducing the outlier the MSE loss is high, the gradient descent algorithm,
tries to converge slowly and minimise the squares
But, in MAE the loss will be less affacted by outliers, resulting in lower loss values and faster convergance.
"""
# Out:
# '\nNow we can see that, after introducing the outlier the MSE loss is high, the gradient descent algorithm,\ntries to converge slowly and minimise the squares\nBut, in MAE the loss will be less affacted by outliers, resulting in lower loss values and faster convergance.\n'
